# %%
def area_rectangulo(base, altura):
  return base * altura

area_rectangulo(15, 10)
# Out:
# 150

# %%
import math

def area_circulo (radio):
  return math.pi * radio**2

area_circulo(5)
# Out:
# 78.53981633974483

# %%
def relacion(num1, num2):
  if num1 > num2:
    return 1
  elif num1 < num2:
    return -1
  elif num1 == num2:
    return 0

print(relacion(5, 10), relacion(10, 5), relacion(5, 5))
# Out:
# -1 1 0

# %%
def intermedio (num1, num2):
  return (num1 + num2)/2

print(intermedio (-12, 24))
# Out:
# 6.0

# %% [markdown]
# Función recortar con n+umero inf y numero sup

# %%
def recortar(num, lim_inf, lim_sup):
  return max(min(num, lim_sup), lim_inf)

recortar(15, 0, 10)
# Out:
# 10

# %% [markdown]
# Función para separa pares e impares

# %%
numeros=[6,5,2,1,7]

def separar(*args):
  lista = sorted(args)
  pares = []
  impares = []
  for arg in lista:
    if arg % 2 == 0:
      pares.append(arg)
    else:
      impares.append(arg)      
  return pares, impares

pares, impares = separar(*numeros)
print(pares)
print(impares)
# Out:
# [2, 6]
# [1, 5, 7]
