# %%
import pandas as pd
df = pd.read_excel('https://query.data.world/s/f4ffgkq33sukbstftztj3a4m4b2wfa')
df.head()
# Out:
#    commandment_number                                commandment_concept  \
# 0                 1.0                               Know there is a G-d
# 1                 2.0  Do not entertain thoughts of other gods beside...
# 2                 3.0            Know that G-d is One, a complete Unity
# 3                 4.0                                          Love G-d
# 4                 5.0                               Fear G-d reverently
#
#   commandment_polarity reference_id  \
# 0                    P     EXO 20:2
# 1                    N     EXO 20:3
# 2                    P      DEU 6:4
# 3                    P      DEU 6:5
# 4                    P    DEU 10:20
#
#                                    scripture_english  \
# 0  "I am the LORD your God, who brought you out o...
# 1           "You shall have no other gods before Me.
# 2  "Hear, O Israel! The LORD is our God, the LORD...
# 3  "You shall love the LORD your God with all you...
# ...
