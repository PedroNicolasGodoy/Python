# %% [markdown]
# Ejercicio 2 POO - Bicicleta

# %%
from datetime import datetime

class Bicicleteria():
  def __init__(self, bicicletas=0, ganancias=0, cantidad_de_ventas=0):
      self.__bicicletas=bicicletas
      self.ganancias=ganancias
      self.cantidad_de_ventas=cantidad_de_ventas

  def vender_bicicleta(self, bicicletas):
      if bicicletas > self.__bicicletas:
          return f"No hay stock suficiente"
      else:
          self.__bicicletas -= bicicletas
          return self.__bicicletas

  def comprar_bicicleta(self, bicicletas):
      if bicicletas < 0:
          return f"ingrese una cantidad positiva"
      else:
          self.__bicicletas += bicicletas
          return self.__bicicletas
  
  def ganancias (self):
    return self.ganancias


  class Bicicleta():
    def __init__(self, modelo, nro_de_serie, anio, precio):
      self.modelo=modelo
      self.__nro_de_serie=nro_de_serie
      self.anio=datetime.strptime(anio, "%d/%m/%y")
      self.__precio=precio

    def modelo (self):
      return self. modelo

    def anio (self):
      return self.anio
      
    def get__precio(self):
      return self.precio

    def get__nro_de_serie(self):
      return self.nro_de_serie

    def set__precio(self, precio):
      self.precio = precio
      return f" El cambio de precio se realizó correctamente"
    def mostrar (self):
      return f" Mi modelo es {self.modelo}, el número de serie {self.__nro_de_serie}, año de fabricación {self.anio}, precio U$ {self.__precio}."

# Clase Bicicleteria
c1=Bicicleteria(10, 1, 1)
# print(c1.comprar_bicicleta(5))

print(c1.vender_bicicleta(3))

# Clase Bicicleta
# bici1=Bicicleteria.Bicicleta('Marlin 5', 'M0001', '01/01/22', 10000)
# bici2=Bicicleteria.Bicicleta('Marlin 6', 'M0022', '02/01/22', 15000)
# bici3=Bicicleteria.Bicicleta('Marlin 5', 'M0002', '01/02/20', 7000)
# bici4=Bicicleteria.Bicicleta('Marlin 4', 'M0001', '10/02/22', 7000)
# print(bici1.mostrar())
# print(bici2.mostrar())
# print(bici3.mostrar())
# print(bici4.mostrar())
# Out:
# 7

# %% [markdown]
# Ejericio 3 Diccionario

# %%
import json

ruta="/content/sample_data"

HeroesDicc={}

HeroesDicc['DC']=[]
HeroesDicc['DC'].append({
                    "nombre":"Flash",
                    "identidadSecreta":"Bartholomew Henry Barry Allem",
                    "poderes":["inmensa velocidad", "agilidad", "Electrokinesis"]})

HeroesDicc['DC'].append({
                    "nombre":"Batman",
                    "identidadSecreta":"Bruce Wayne",
                    "poderes":["super fuerza", "super velocidad"]})

HeroesDicc['DC'].append({
                    "nombre":"Superman",
                    "identidadSecreta":"Clark Joseph Kent",
                    "poderes":["super fuerza", "resistencia", "agilidad", "reflejos", "durabilidad", "sentidos y longevidad"]})

with open(ruta + "/super_heroes.json", 'w') as file:
    json.dump(HeroesDicc, file, indent=4)

with open(ruta + "/super_heroes.json") as file:
  x = json.load(file)
  print(x)
# Out:
# {'DC': [{'nombre': 'Flash', 'identidadSecreta': 'Bartholomew Henry Barry Allem', 'poderes': ['inmensa velocidad', 'agilidad', 'Electrokinesis']}, {'nombre': 'Batman', 'identidadSecreta': 'Bruce Wayne', 'poderes': ['super fuerza', 'super velocidad']}, {'nombre': 'Superman', 'identidadSecreta': 'Clark Joseph Kent', 'poderes': ['super fuerza', 'resistencia', 'agilidad', 'reflejos', 'durabilidad', 'sentidos y longevidad']}]}

# %% [markdown]
# Analisis de Datos Ejercicio 4

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df_titanic = pd.read_csv('https://raw.githubusercontent.com/NotAyushXD/Titanic-dataset/master/train.csv')
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#información de los primero 5 pasajeros

df_titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# mostrar la información de últimos 5 pasajeros

df_titanic.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#mostrar la cantidad de columnas

df_titanic.shape[1]
# Out:
# 12

# %%
#mostrar cantidad de filas

len(df_titanic.index)
# Out:
# 891

# %%
# cuanto dinero se recaudó en el viaje

Total_Fare=df_titanic['Fare'].sum()

print(f" el total de dinero recaudado es U$ {Total_Fare}")
# Out:
#  el total de dinero recaudado es U$ 28693.9493

# %%
# cuál es la cantidad de personas que viajaban en primera clase
import numpy as np

total_primera_clase = df_titanic.loc[df_titanic['Pclass'] == 1].sum()

print(f" el total de pasajeros en primera clase es {total_primera_clase}")
# Out:
#  el total de pasajeros en primera clase es PassengerId                                                99705
# Survived                                                     136
# Pclass                                                       216
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex            femalefemalemalefemalemalemalemalefemalemalema...
# Age                                                      7111.42
# SibSp                                                         90
# Parch                                                         77
# Ticket         PC 175991138031746311378311378819950PC 17601PC...
# Fare                                                  18177.4125
# dtype: object
# ...

# %%
# grafica la cantidad de personas que vianjaban por clase en el barco

df_titanic['Pclass'].value_counts().plot(kind='bar')
